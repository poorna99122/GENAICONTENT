# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in d:\studynew\gen ai content\miniconda\lib\site-packages (3.9.4)
# Requirement already satisfied: click in d:\studynew\gen ai content\miniconda\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in d:\studynew\gen ai content\miniconda\lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in d:\studynew\gen ai content\miniconda\lib\site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in d:\studynew\gen ai content\miniconda\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in d:\studynew\gen ai content\miniconda\lib\site-packages (from click->nltk) (0.4.6)

# %%
# !pip show nltk
# Out:
# Name: nltk
# Version: 3.9.4
# Summary: Natural Language Toolkit
# Home-page: https://www.nltk.org/
# Author: NLTK Team
# Author-email: nltk.team@gmail.com
# License: Apache License, Version 2.0
# Location: D:\StudyNew\GEN AI content\miniconda\Lib\site-packages
# Requires: click, joblib, regex, tqdm
# Required-by:

# %%
corpus = """Hello Welcome, to Krish Naik's NLP Tutorials.
Please do watch the entire course! to become an expert in NLP.
"""

# %%
print(corpus)
# Out:
# Hello Welcome, to Krish Naik's NLP Tutorials.
# Please do watch the entire course! to become an expert in NLP.

# %%
## Tokenization 
## Paragraph --> Sententence 
from nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)

# %%
documents
# Out:
# ["Hello Welcome, to Krish Naik's NLP Tutorials.",
#  'Please do watch the entire course!',
#  'to become an expert in NLP.']

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome, to Krish Naik's NLP Tutorials.
# Please do watch the entire course!
# to become an expert in NLP.

# %%
print(corpus)
# Out:
# Hello Welcome, to Krish Naik's NLP Tutorials.
# Please do watch the entire course! to become an expert in NLP.

# %%
## Tokenization
## Paragraph --> words
## sentence --> words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'an',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
type(words)
# Out:
# list

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Krish', 'Naik', "'s", 'NLP', 'Tutorials', '.']
# ['Please', 'do', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'an', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'",
#  's',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'an',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
## Here, a full stop is not treated as a separate word except for the last full stop
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'an',
#  'expert',
#  'in',
#  'NLP',
#  '.']
