# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\poorn\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
## Q&A, chatbots, text summarization
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# %%
'''
POS- Noun-n
verb-v
adjective-a
adverb-r
'''
lemmatizer.lemmatize("going", pos='v')
# Out:
# 'go'

# %%
words=["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %%
for word in words:
    print(word + "-->" + lemmatizer.lemmatize(word,pos='v'))
# Out:
# eating-->eat
# eats-->eat
# eaten-->eat
# writing-->write
# writes-->write
# programming-->program
# programs-->program
# history-->history
# finally-->finally
# finalized-->finalize

# %%
lemmatizer.lemmatize("goes",pos='v')
# Out:
# 'go'

# %%
lemmatizer.lemmatize('fairly'),lemmatizer.lemmatize('sportingly')
# Out:
# ('fairly', 'sportingly')

# %%
lemmatizer.lemmatize('fairly',pos='v'),lemmatizer.lemmatize('sportingly',pos='v')
# Out:
# ('fairly', 'sportingly')

# %%
## Note -> which one takes more time WordNetLemmatizer or Stemming ?

# %%
## Ans is WordNetLemmatizer -> because NLTK provides WordNetLemmatizer as a thin wrapper around the wordnet corpus it is going to 
## compare from there so this will basically take time
